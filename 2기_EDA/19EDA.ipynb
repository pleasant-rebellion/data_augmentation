# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

dataset = pd.read_csv('dataset/train/train.csv')

train_dataset, dev_dataset = train_test_split(dataset, stratify= dataset.label, test_size= 0.1, random_state=1004)

label = train_dataset['label']

print(train_dataset.shape)
print(train_dataset.head(5))
# Out:
# (29223, 6)
#           id                                           sentence  \
# 22874  22874  KMH그룹(회장 최상주)이 운영하는 종합여행기업 보물섬투어는 뉴캐슬 지역의 ‘헌터밸...
# 8793    8793  아인슈타인 본인을 비롯한 여러 물리학자들은 만유인력 법칙과 특수상대론을 조화시킬 새...
# 5285    5285  서울대 본부 측은 2011년 3월 총장, 교수, 외부위원 등으로 구성된 '국립대학법...
# 21877  21877  박능후 중앙재난안전대책본부 1차장(보건복지부 장관)은 24일 “(코로나19의)확산세...
# 23172  23172  회의에는 주민 대표, 사회단체, 전문가, 지역 도의원과 시의원, 전라남도, 여수시,...
#
#                                           subject_entity  \
# 22874  {'word': 'KMH', 'start_idx': 0, 'end_idx': 2, ...
# 8793   {'word': '아인슈타인', 'start_idx': 0, 'end_idx': 4...
# 5285   {'word': '서울대학교', 'start_idx': 48, 'end_idx': ...
# 21877  {'word': '보건복지부', 'start_idx': 19, 'end_idx': ...
# 23172  {'word': '영산강', 'start_idx': 47, 'end_idx': 49...
#
#                                            object_entity  \
# 22874  {'word': '최상주', 'start_idx': 9, 'end_idx': 11,...
# 8793   {'word': '물리학자', 'start_idx': 17, 'end_idx': 2...
# 5285   {'word': '국립대학법인', 'start_idx': 41, 'end_idx':...
# 21877  {'word': '박능후', 'start_idx': 0, 'end_idx': 2, ...
# 23172  {'word': '전라남도', 'start_idx': 36, 'end_idx': 3...
#
#                            label           source
# 22874  org:top_members/employees         wikitree
# 8793                 no_relation        wikipedia
# 5285                 no_relation        wikipedia
# 21877  org:top_members/employees  policy_briefing
# 23172                no_relation         wikitree

# %%
print(label.value_counts())
print(label.value_counts().index)
# Out:
# no_relation                            8581
# org:top_members/employees              3856
# per:employee_of                        3216
# per:title                              1893
# org:member_of                          1679
# org:alternate_names                    1188
# per:origin                             1111
# org:place_of_headquarters              1075
# per:date_of_birth                      1017
# per:alternate_names                     901
# per:spouse                              715
# per:colleagues                          481
# per:parents                             468
# org:founded                             405
# org:members                             378
# per:date_of_death                       376
# org:product                             342
# per:children                            274
# per:place_of_residence                  174
# per:other_family                        171
# per:place_of_birth                      149
# org:founded_by                          140
# per:product                             125
# per:siblings                            122
# org:political/religious_affiliation      88
# per:religion                             86
# per:schools_attended                     74
# org:dissolved                            59
# org:number_of_employees/members          43
# per:place_of_death                       36
# Name: label, dtype: int64
# Index(['no_relation', 'org:top_members/employees', 'per:employee_of',
#        'per:title', 'org:member_of', 'org:alternate_names', 'per:origin',
#        'org:place_of_headquarters', 'per:date_of_birth', 'per:alternate_names',
#        'per:spouse', 'per:colleagues', 'per:parents', 'org:founded',
#        'org:members', 'per:date_of_death', 'org:product', 'per:children',
#        'per:place_of_residence', 'per:other_family', 'per:place_of_birth',
#        'org:founded_by', 'per:product', 'per:siblings',
#        'org:political/religious_affiliation', 'per:religion',
#        'per:schools_attended', 'org:dissolved',
#        'org:number_of_employees/members', 'per:place_of_death'],
#       dtype='object')

# %%
replace_label = ['per:alternate_names', 'org:alternate_names', 'per:alternate_name', 'per:other_family', 'per:colleagues', 'per:siblings', 'per:spouse']
replace_member = ['org_members', 'org:menbers_of']
replace_family = ['per:parents', 'per:children']

id = len(train_dataset)
newData = []

for i in range(len(train_dataset)):
    if train_dataset.iloc[i, 4] in replace_label:
        data = train_dataset.iloc[i, :]
        
        data['id'] = id
        tmp = data['subject_entity']
        data['subject_entity'] = data['object_entity']
        data['object_entity'] = tmp

        newData.append(data)
        id += 1
    elif train_dataset.iloc[i, 4] in replace_member:
        data = train_dataset.iloc[i, :]
        
        data['id'] = id
        tmp = data['subject_entity']
        data['subject_entity'] = data['object_entity']
        data['object_entity'] = tmp

        if data['label'] == 'org_members':
            data['label'] = 'org:menbers_of'
        else: data['label'] = 'org_members'

        newData.append(data)
        id += 1
    elif train_dataset.iloc[i, 4] in replace_family:
        data = train_dataset.iloc[i, :]
        
        data['id'] = id
        tmp = data['subject_entity']
        data['subject_entity'] = data['object_entity']
        data['object_entity'] = tmp

        if data['label'] == 'per:parents': 
            data['label'] = 'per:children'
        else: data['label'] = 'per:parents'

        newData.append(data)
        id += 1
# Out:
# <ipython-input-3-79c0e912d7b5>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['id'] = id
# <ipython-input-3-79c0e912d7b5>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['subject_entity'] = data['object_entity']
# <ipython-input-3-79c0e912d7b5>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['object_entity'] = tmp
# <ipython-input-3-79c0e912d7b5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['id'] = id
# <ipython-input-3-79c0e912d7b5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['subject_entity'] = data['object_entity']
# <ipython-input-3-79c0e912d7b5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['object_entity'] = tmp
# <ipython-input-3-79c0e912d7b5>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label'] = 'per:children'
# <ipython-input-3-79c0e912d7b5>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: data['label'] = 'per:parents'

# %%
selected_label = []
under_2000_name = [l for l in label.value_counts().index]
under_2000 = [l for l in label.value_counts()]

for i in range(len(under_2000)):
    if under_2000[i] < 2000:
        selected_label.append(under_2000_name[i])

print(selected_label)
# Out:
# ['per:title', 'org:member_of', 'org:alternate_names', 'per:origin', 'org:place_of_headquarters', 'per:date_of_birth', 'per:alternate_names', 'per:spouse', 'per:colleagues', 'per:parents', 'org:founded', 'org:members', 'per:date_of_death', 'org:product', 'per:children', 'per:place_of_residence', 'per:other_family', 'per:place_of_birth', 'org:founded_by', 'per:product', 'per:siblings', 'org:political/religious_affiliation', 'per:religion', 'per:schools_attended', 'org:dissolved', 'org:number_of_employees/members', 'per:place_of_death']

# %%
import random
import re

def Random_Insertion(text, sub_word, ob_word, sub_length, ob_length):
    word_list = ['오늘', '내일', '어제', '머신', '러닝']
    new_word = word_list[random.randint(0, len(word_list) - 1)]

    text_len = len(text.split())
    text_word_list = text.split()

    sub_start = 0
    ob_start = 0

    for idx in range(len(text_word_list)):
        if re.search(sub_word , text_word_list[idx]):
            sub_start = idx
            break
    
    sub_end = sub_start + sub_length
    sub_index = [i for i in range(sub_start, sub_end)]

    for idx in range(len(text_word_list)):
        if re.search(ob_word , text_word_list[idx]):
            ob_start = idx
            break

    ob_end = ob_start + ob_length
    ob_index = [i for i in range(ob_start, ob_end)]

    valid_num = [i for i in range(0, text_len) if i not in sub_index and i not in ob_index]
    
    if valid_num != []:
        target_num = random.choice(valid_num)
        text_word_list.insert(target_num, new_word)
    else:
        target_num = random.randInt(0, text_len)
        text_word_list.insert(target_num, new_word)

    return ' '.join(text_word_list)

# %%
for idx in range(len(train_dataset)):
    if train_dataset.iloc[idx, 4] in selected_label:
        data = train_dataset.iloc[idx, :]

        subject_dict = {}
        subject_entity = eval(data['subject_entity'])
        subject_word = subject_entity['word']
        subject_word_list = subject_word.split()
        
        object_dict = {}
        object_entity = eval(data['object_entity'])
        object_word = object_entity['word']
        object_word_list = object_word.split()

        try:
            data['id'] = id
            data['sentence'] = Random_Insertion(data['sentence'], subject_word_list[0], object_word_list[0], len(subject_word.split()), len(object_word.split()))
            
            subject_dict = {'word': f'{subject_word}', 'start_idx': re.search(subject_word, data['sentence']).start(), 'end_idx': re.search(subject_word, data['sentence']).end()-1}
            object_dict = {'word': f'{object_word}', 'start_idx': re.search(object_word, data['sentence']).start(), 'end_idx': re.search(object_word, data['sentence']).end()-1}

            data['subject_entity'] = subject_dict
            data['object_entity'] = object_dict

            newData.append(data)
            id += 1
        except:
            continue
# Out:
# <ipython-input-6-71d4f5a16c7a>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['id'] = id
# <ipython-input-6-71d4f5a16c7a>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sentence'] = Random_Insertion(data['sentence'], subject_word_list[0], object_word_list[0], len(subject_word.split()), len(object_word.split()))
# <ipython-input-6-71d4f5a16c7a>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['subject_entity'] = subject_dict
# <ipython-input-6-71d4f5a16c7a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['object_entity'] = object_dict

# %%
newDF = pd.DataFrame(newData, columns=['id', 'sentence', 'subject_entity', 'object_entity', 'label', 'source'])
train_dataset = train_dataset.append(newDF, ignore_index=True)

print(newDF['label'].value_counts())
print(newDF.shape)

print(train_dataset['label'].value_counts())
print(train_dataset.shape)

print(dev_dataset['label'].value_counts())
print(dev_dataset.shape)

newDF.to_csv('dataset/train/addDataset.csv', index=False)
train_dataset.to_csv('dataset/train/train_dataset.csv', index=False)
dev_dataset.to_csv('dataset/train/dev_dataset.csv', index=False)
# Out:
# <ipython-input-7-ac193db41395>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_dataset = train_dataset.append(newDF, ignore_index=True)
# org:alternate_names                    2364
# per:title                              1887
# per:alternate_names                    1776
# org:member_of                          1653
# per:spouse                             1421
# per:origin                             1104
# org:place_of_headquarters              1069
# per:date_of_birth                      1014
# per:colleagues                          962
# per:children                            736
# per:parents                             735
# org:founded                             403
# org:members                             375
# per:date_of_death                       368
# per:other_family                        340
# org:product                             337
# per:siblings                            243
# per:place_of_residence                  173
# per:place_of_birth                      147
# org:founded_by                          139
# per:product                             125
# org:political/religious_affiliation      88
# per:religion                             86
# per:schools_attended                     74
# org:dissolved                            58
# org:number_of_employees/members          43
# per:place_of_death                       35
# Name: label, dtype: int64
# (17755, 6)
# no_relation                            8581
# org:top_members/employees              3856
# per:title                              3780
# org:alternate_names                    3552
# org:member_of                          3332
# per:employee_of                        3216
# per:alternate_names                    2677
# per:origin                             2215
# org:place_of_headquarters              2144
# per:spouse                             2136
# per:date_of_birth                      2031
# per:colleagues                         1443
# per:parents                            1203
# per:children                           1010
# org:founded                             808
# org:members                             753
# per:date_of_death                       744
# org:product                             679
# per:other_family                        511
# per:siblings                            365
# per:place_of_residence                  347
# per:place_of_birth                      296
# org:founded_by                          279
# per:product                             250
# org:political/religious_affiliation     176
# per:religion                            172
# per:schools_attended                    148
# org:dissolved                           117
# org:number_of_employees/members          86
# per:place_of_death                       71
# Name: label, dtype: int64
# (46978, 6)
# no_relation                            953
# org:top_members/employees              428
# per:employee_of                        357
# per:title                              210
# org:member_of                          187
# org:alternate_names                    132
# per:origin                             123
# org:place_of_headquarters              120
# per:date_of_birth                      113
# per:alternate_names                    100
# per:spouse                              80
# per:colleagues                          53
# per:parents                             52
# org:founded                             45
# org:members                             42
# per:date_of_death                       42
# org:product                             38
# per:children                            30
# per:place_of_residence                  19
# per:other_family                        19
# per:place_of_birth                      17
# org:founded_by                          15
# per:product                             14
# per:siblings                            14
# org:political/religious_affiliation     10
# per:religion                            10
# per:schools_attended                     8
# org:dissolved                            7
# org:number_of_employees/members          5
# per:place_of_death                       4
# Name: label, dtype: int64
# (3247, 6)
